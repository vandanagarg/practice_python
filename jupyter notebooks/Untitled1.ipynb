# %%
#Set working directory
import os
os.chdir("D:\edwisor assignment")

# %%
#Check current working directory
os.getcwd()
# Out:
# 'D:\\edwisor assignment'

# %%
#Import libraries
import os
import pandas as pd
import numpy as np
import matplotlib as mlt

# %%
#Load csv data in python
#2nd row to be skipped
df_csv = pd.read_csv("IMDB_data.csv", encoding = "ISO-8859-1", skiprows = [2])

# %%
#Extract the unique genres and its count and store in data frame with index key.
df1= df_csv['Genre'].value_counts().to_frame().reset_index().rename(columns={"index": "value"})

# %%
#Convert the required data types
df2_csv = df_csv.astype(object)

# %%
#Sort the genre by its name
df_csv = df_csv.sort_values('Genre', ascending = True)

# %%
#Create new variable whose values should be square of difference between imdbrating and imdbvotes.
#df_mtcars['NewVar'] = np.log2(df_mtcars['cyl'])
#df_mtcars = df_mtcars.astype(object)
#df_csv['imdbVotes'] = df_csv['imdbVotes'].astype(float) 
df_csv['sqr_diff'] = 0  # creating a new variable and assigning default value 0 to it.
for i in range(len(df_csv)): 
    df_csv[diff].loc[i] = df_csv['imdbRating'].loc[i] - df_csv['imdbVotes'].loc[i]
    df_csv['sqr_diff'].loc[i] = df_csv[diff].loc[i]*df_csv[diff].loc[i]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-42ccd7efa3fc> in <module>()
#       4 df_csv['sqr_diff'] = 0  # creating a new variable and assigning default value 0 to it.
#       5 for i in range(len(df_csv)):
# ----> 6     df_csv[diff].loc[i] = df_csv['imdbRating'].loc[i] - df_csv['imdbVotes'].loc[i]
#       7     df_csv['sqr_diff'].loc[i] = df_csv[diff].loc[i]*df_csv[diff].loc[i]
#       8
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
#df_csv['imdbVotes'] = df_csv['imdbVotes'].astype(int) 
#df3_csv = df_csv.astype(int)
#df3_csv = ord(df_csv)
#type(df_csv['imdbVotes'])
#df_csv['imdbVotes'] = ord(df_csv['imdbVotes'])
df_csv['imdbVotes'] = df_csv['imdbVotes'].astype(str)

# %%
type(df_csv['imdbVotes'])
# Out:
# pandas.core.series.Series

# %%
df_csv[diff] = df_csv['imdbRating'].astype(str) - df_csv['imdbVotes'].astype(str)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#     675         try:
# --> 676             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#     677         except TypeError:
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     203     if use_numexpr:
# --> 204         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     205     return _evaluate_standard(op, op_str, a, b)
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b, truediv, reversed, **eval_kwargs)
#     118     if result is None:
# --> 119         result = _evaluate_standard(op, op_str, a, b)
#     120
#
# ...

# %%
type(df_csv)
# Out:
# pandas.core.frame.DataFrame

# %%
#df_csv['imdbVotes'] = df_csv['imdbVotes'].astype(list) 
#df_csv['imdbRating'] = df_csv['imdbRating'].astype(list) 
df_csv['subs']= ([df_csv['imdbRating']]) - ([df_csv['imdbVotes']])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-5929f528fb6e> in <module>()
#       2 #df_csv['imdbVotes'] = df_csv['imdbVotes'].astype(list)
#       3 #df_csv['imdbRating'] = df_csv['imdbRating'].astype(list)
# ----> 4 df_csv['subs']= ([df_csv['imdbRating']]) - ([df_csv['imdbVotes']])
#
# TypeError: unsupported operand type(s) for -: 'list' and 'list'

# %%
df_csv['imdbVotes']= pd.to_numeric(df_csv['imdbVotes'],errors='ignore')

# %%
type(df_csv['imdbVotes'])
# Out:
# pandas.core.series.Series

# %%
df_csv['imdbRating'] = df_csv['imdbRating'].astype(list)

# %%
type(df_csv['imdbRating'])
# Out:
# pandas.core.series.Series

# %%
#df_csv
#df_csv['Total']= df_csv.iloc[:,3:10].sum(axis=1)
df_csv['sum']= df_csv.iloc[:,3:5].sum(axis=1)

# %%
df_csv
# Out:
#                                                    Plot  \
# 0     Despite his tarnished reputation after the eve...
# 1     Based on the novel written by Stephen Chbosky,...
# 2     Mike Lane is a thirty-year old living in Tampa...
# 3     When Bond's latest assignment goes gravely wro...
# 4     Against medical advice and without the knowled...
# 5     A shy senior and a down-to-earth junior fall i...
# 6     In California, the former Navy SEAL Chon and h...
# 7     Meet the Borgens. William Borgens is an acclai...
# 8     In 1874, in the Imperial Russia, the aristocra...
# 9     In the 1960s, Richard Kuklinski is working as ...
# 10    The sunrise blinds the early risers of the cit...
# 11    A mysterious traveler infiltrates a dangerous ...
# 12    In both its story on and off the screen, 'Flan...
# 13    Hailey is in an unhappy marriage but she devel...
# 14    Yannick has to deal with the haunting by himse...
# 15    Seduced by the haunting beauty of a remote mar...
# ...
